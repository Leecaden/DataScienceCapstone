# %% [markdown]
# # Food Battle SG!

# %% [markdown]
# Singapore (SG) is an island-state located in South East Asia, south of Johor Bahru, Singapore. Although it is a country with mere 721.5 sq km landspace, the country is well-known for quite a few things: being one of the financial hub of Asia, having the best universities in Asia and being called the <a href = https://edition.cnn.com/specials/asia/future-cities-singapore>city of the future</a>. <br><br>
# While all these sound impressive, the city state is better known to tourists as the <i>Food Heaven</i>. Singapore has all the delicious food from South East Asia and all the world. Food is arguably one of the things that keep the multi-racial cohesive. Food is the common interest of the people. The people appreciate different race and culture through food sharing. Food, some may say, is what defines Singapore. <br><br>
# In this data story, we will be exploring the food in different towns of Singapore. Using Foursquare as a data source, we shall explore how each town differ from each other when it comes to food establishments. Through this story, we shall also debunk a common perception that there are <a href = https://www.quora.com/What-are-the-major-differences-between-West-Side-and-East-Side-Singaporeans>differences between the East and the West sides of Singapore </a>. Is it true that the East has better food options than the west? We shall find out!

# %%
# import libraries
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt # plots
import matplotlib.cm as cm # confusion matrix
import matplotlib.colors as colors # color palete

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# # 1. Import Location Data
# Here, we shall simplify the locations by taking the MRT stations as the references. The MRT (Mass Rapid Train) is the subway system in Singapore. It has a total of 141 stations connecting every corners of the city-state. The MRT provides great convenience to the people, and it is arguably the most important transportation system in the city. Most housing and commercial properties are built around the stations. Hence, it is safe to assume that most food establishments are built around the stations, where human traffic is the highest.

# %%
# All the data of the mrt stations are saved in a json file named mrt_stations.json
# data source: https://github.com/xkjyeah/singapore-postal-codes
with open('mrt_stations.json', "r") as f:
    data = json.load(f)

# %%
# Extract keys of the primary dictionary in json file
keys = []
for key in data[0].keys():
    keys.append(key)
print(keys)
# Out:
# ['Possible Locations', 'Station', 'Station Name']

# %%
# Extract the required data for our analysis, i.e. Station Name, Station, Postal Code, Lat, Long
sg_mrt = []

for item in data:
    new_dict = {}
    new_dict[keys[2].upper()] = item[keys[2]]
    new_dict[keys[1].upper()] = item[keys[1]]
    Address = item[keys[0]][0]
    new_dict['LATITUDE'] = Address['LATITUDE']
    new_dict['LONGITUDE'] = Address['LONGITUDE']
    new_dict['POSTAL'] = Address['POSTAL']
    sg_mrt.append(new_dict)

print(sg_mrt[:2])
print(len(sg_mrt))
# Out:
# [{'STATION NAME': 'Jurong East', 'STATION': 'NS1', 'LATITUDE': '1.33315261987297', 'LONGITUDE': '103.742286544006', 'POSTAL': '609690'}, {'STATION NAME': 'Bukit Batok', 'STATION': 'NS2', 'LATITUDE': '1.34903410858812', 'LONGITUDE': '103.749566764129', 'POSTAL': '659958'}]
# 141

# %%
# Convert required data into a dataframe for easy analysis
sg_df = pd.DataFrame(sg_mrt)
sg_df = sg_df[['STATION NAME','STATION','POSTAL','LONGITUDE','LATITUDE']]
# data type conversion: string to float for LONGITUDE and LATITUDE
sg_df['LONGITUDE'] = sg_df['LONGITUDE'].apply(lambda x: float(x))
sg_df['LATITUDE'] = sg_df['LATITUDE'].apply(lambda x: float(x))
print(sg_df.shape)
sg_df.head()
# Out:
# (141, 5)
#     STATION NAME STATION  POSTAL   LONGITUDE  LATITUDE
# 0    Jurong East     NS1  609690  103.742287  1.333153
# 1    Bukit Batok     NS2  659958  103.749567  1.349034
# 2   Bukit Gombak     NS3  659083  103.751791  1.358612
# 3  Choa Chu Kang     NS4  689810  103.744371  1.385363
# 4        Yew Tee     NS5  689715  103.747405  1.397535

# %%
# Removes duplicated stations
# Some stations are interchanges - i.e. one station may appear on two different subway lines
# Need to remove duplicates as duplicates does not give us any additional useful information
sg_df=sg_df.drop_duplicates(subset=['STATION NAME'],keep = 'first')
print(sg_df.shape)
# Out:
# (119, 5)

# %% [markdown]
# # 2. Generate Singapore Map with the MRT Stations

# %%
# Get Longitude and Latitude of Central SG
address = 'Singapore, SG'

geolocator = Nominatim(user_agent="on_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Singapore are 1.2904753, 103.8520359.

# %%
# create map of Singapore using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(sg_df['LATITUDE'], sg_df['LONGITUDE'], sg_df['STATION NAME']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup = label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  

# Display Map
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As mentioned, the MRT system is expansive and covers most residential and commercial areas in the city. Click on the bubble to see the station name.

# %% [markdown]
# # 3. Extract Data from Foursquare

# %%
# Define credentials
CLIENT_ID = '' # Foursquare ID omitted for privacy
CLIENT_SECRET = '' # Foursquare Secret omitted for privacy
VERSION = ''
LIMIT = 30

# %%
# Create function that queries the API to get required data
# Required data here are venue names, location, venue category
def getVenue(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Execute function - expect this to take a little longer 
# since we are querying for a total of 119 locations
sg_venues = getVenue(names=sg_df['STATION NAME'],
                                   latitudes=sg_df['LATITUDE'],
                                   longitudes=sg_df['LONGITUDE']
                                  )
# Out:
# Jurong East
# Bukit Batok
# Bukit Gombak
# Choa Chu Kang
# Yew Tee
# Kranji
# Marsiling
# Woodlands
# Admiralty
# Sembawang
# Yishun
# Khatib
# Yio Chu Kang
# Ang Mo Kio
# Bishan
# Braddell
# Toa Payoh
# Novena
# Newton
# Orchard
# Somerset
# Dhoby Ghaut
# City Hall
# Raffles Place
# Marina Bay
# Marina South Pier
# Pasir Ris
# Tampines
# Simei
# Tanah Merah
# Bedok
# Kembangan
# Eunos
# Paya Lebar
# Aljunied
# Kallang
# Lavender
# Bugis
# Tanjong Pagar
# Outram Park
# Tiong Bahru
# Redhill
# Queenstown
# Commonwealth
# Buona Vista
# Dover
# Clementi
# Chinese Garden
# Lakeside
# Boon Lay
# Pioneer
# Joo Koon
# Gul Circle
# Tuas Crescent
# Tuas West Road
# Tuas Link
# Expo
# Changi Airport
# HarbourFront
# Chinatown
# Clarke Quay
# Little India
# Farrer Park
# Boon Keng
# Potong Pasir
# Woodleigh
# Serangoon
# Kovan
# Hougang
# Buangkok
# Sengkang
# Punggol
# Bras Basah
# Esplanade
# Promenade
# Nicoll Highway
# Stadium
# Mountbatten
# Dakota
# MacPherson
# Tai Seng
# Bartley
# Lorong Chuan
# Marymount
# Caldecott
# Botanic Gardens
# Farrer Road
# Holland Village
# one-north
# Kent Ridge
# Haw Par Villa
# Pasir Panjang
# Labrador Park
# Telok Blangah
# Bayfront
# Bukit Panjang
# Cashew
# Hillview
# Beauty World
# King Albert Park
# Sixth Avenue
# Tan Kah Kee
# Stevens
# Rochor
# Downtown
# Telok Ayer
# Fort Canning
# Bencoolen
# Jalan Besar
# Bendemeer
# Geylang Bahru
# Mattar
# Ubi
# Kaki Bukit
# Bedok North
# Bedok Reservoir
# Tampines West
# Tampines East
# Upper Changi

# %%
# A brief look at the number of venue category in each neighborhood
sg_venues.groupby('Neighborhood').count()
# Out:
#                  Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Admiralty                           30                      30     30
# Aljunied                            30                      30     30
# Ang Mo Kio                          30                      30     30
# Bartley                             29                      29     29
# Bayfront                            30                      30     30
# Beauty World                        30                      30     30
# Bedok                               30                      30     30
# Bedok North                         30                      30     30
# Bedok Reservoir                     30                      30     30
# Bencoolen                           30                      30     30
# Bendemeer                           30                      30     30
# Bishan                              30                      30     30
# Boon Keng                           30                      30     30
# Boon Lay                            30                      30     30
# Botanic Gardens                     30                      30     30
# Braddell                            30                      30     30
# Bras Basah                          30                      30     30
# Buangkok                            28                      28     28
# Bugis                               30                      30     30
# Bukit Batok                         30                      30     30
# Bukit Gombak                        30                      30     30
# Bukit Panjang                       30                      30     30
# Buona Vista                         30                      30     30
# Caldecott                           30                      30     30
# Cashew                              30                      30     30
# Changi Airport                      30                      30     30
# Chinatown                           30                      30     30
# Chinese Garden                      30                      30     30
# Choa Chu Kang                       30                      30     30
# City Hall                           30                      30     30
# ...                                ...                     ...    ...
# Sembawang                           30                      30     30
# Sengkang                            30                      30     30
# Serangoon                           30                      30     30
# Simei                               30                      30     30
# Sixth Avenue                        30                      30     30
# Somerset                            30                      30     30
# Stadium                             30                      30     30
# Stevens                             30                      30     30
# Tai Seng                            30                      30     30
# Tampines                            30                      30     30
# Tampines East                       30                      30     30
# Tampines West                       30                      30     30
# Tan Kah Kee                         30                      30     30
# Tanah Merah                         30                      30     30
# Tanjong Pagar                       30                      30     30
# Telok Ayer                          30                      30     30
# Telok Blangah                       30                      30     30
# Tiong Bahru                         30                      30     30
# Toa Payoh                           30                      30     30
# Tuas Crescent                        6                       6      6
# Tuas Link                           13                      13     13
# Tuas West Road                       5                       5      5
# Ubi                                 30                      30     30
# Upper Changi                        30                      30     30
# Woodlands                           30                      30     30
# Woodleigh                           30                      30     30
# Yew Tee                             30                      30     30
# Yio Chu Kang                        30                      30     30
# Yishun                              30                      30     30
# one-north                           30                      30     30
#
#                  Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Admiralty                    30               30              30
# Aljunied                     30               30              30
# Ang Mo Kio                   30               30              30
# Bartley                      29               29              29
# Bayfront                     30               30              30
# Beauty World                 30               30              30
# Bedok                        30               30              30
# Bedok North                  30               30              30
# Bedok Reservoir              30               30              30
# Bencoolen                    30               30              30
# Bendemeer                    30               30              30
# Bishan                       30               30              30
# Boon Keng                    30               30              30
# Boon Lay                     30               30              30
# Botanic Gardens              30               30              30
# Braddell                     30               30              30
# Bras Basah                   30               30              30
# Buangkok                     28               28              28
# Bugis                        30               30              30
# Bukit Batok                  30               30              30
# Bukit Gombak                 30               30              30
# Bukit Panjang                30               30              30
# Buona Vista                  30               30              30
# Caldecott                    30               30              30
# Cashew                       30               30              30
# Changi Airport               30               30              30
# Chinatown                    30               30              30
# Chinese Garden               30               30              30
# Choa Chu Kang                30               30              30
# City Hall                    30               30              30
# ...                         ...              ...             ...
# Sembawang                    30               30              30
# Sengkang                     30               30              30
# Serangoon                    30               30              30
# Simei                        30               30              30
# Sixth Avenue                 30               30              30
# Somerset                     30               30              30
# Stadium                      30               30              30
# Stevens                      30               30              30
# Tai Seng                     30               30              30
# Tampines                     30               30              30
# Tampines East                30               30              30
# Tampines West                30               30              30
# Tan Kah Kee                  30               30              30
# Tanah Merah                  30               30              30
# Tanjong Pagar                30               30              30
# Telok Ayer                   30               30              30
# Telok Blangah                30               30              30
# Tiong Bahru                  30               30              30
# Toa Payoh                    30               30              30
# Tuas Crescent                 6                6               6
# Tuas Link                    13               13              13
# Tuas West Road                5                5               5
# Ubi                          30               30              30
# Upper Changi                 30               30              30
# Woodlands                    30               30              30
# Woodleigh                    30               30              30
# Yew Tee                      30               30              30
# Yio Chu Kang                 30               30              30
# Yishun                       30               30              30
# one-north                    30               30              30
#
# [119 rows x 6 columns]

# %%
# Brief look at the different venue category
sg_venues['Venue Category'].unique()
# Out:
# array(['Clothing Store', 'Japanese Restaurant', 'Skating Rink', 'Bakery',
#        'Furniture / Home Store', 'Vegetarian / Vegan Restaurant',
#        'Movie Theater', 'Multiplex', 'Chinese Restaurant',
#        'Shopping Mall', 'Supermarket', 'Bookstore', 'Department Store',
#        'Bubble Tea Shop', 'Indian Restaurant', 'Sushi Restaurant',
#        'Hotpot Restaurant', 'Italian Restaurant', 'Trail',
#        'Korean Restaurant', 'Burger Joint', 'Halal Restaurant', 'Pool',
#        'Fast Food Restaurant', 'Coffee Shop', 'Food Court',
#        'Malay Restaurant', 'Frozen Yogurt Shop', 'Sandwich Place',
#        'Bowling Alley', 'Café', 'Train Station', 'Lingerie Store',
#        'Grocery Store', 'Ice Cream Shop', 'Lake', 'Flea Market',
#        'Steakhouse', 'Golf Course', 'Bar', 'Stadium', 'Asian Restaurant',
#        'Lounge', 'Thai Restaurant', 'Park', 'Playground',
#        'Portuguese Restaurant', 'Beer Garden', 'Cosmetics Shop',
#        'Shoe Store', 'Dessert Shop', 'Pharmacy', 'Music Store',
#        'Gym / Fitness Center', 'Restaurant', 'Diner', 'Gym', 'Building',
#        'Dog Run', 'Bus Stop', 'Tennis Court', 'Bus Station', 'Office',
#        'Go Kart Track', 'Racetrack', 'Monument / Landmark', 'Bus Line',
#        'Lighthouse', 'BBQ Joint', 'Speakeasy', 'Post Office',
#        'Pizza Place', 'College Theater', 'Electronics Store', 'Spa',
#        'Basketball Court', 'Food & Drink Shop', 'Convenience Store',
#        'Shopping Plaza', 'Bistro', 'American Restaurant',
#        'Discount Store', 'Cantonese Restaurant', 'Hong Kong Restaurant',
#        'Noodle House', 'Fried Chicken Joint', 'Tea Room', 'Karaoke Bar',
#        'Hainan Restaurant', 'Ramen Restaurant', 'Video Game Store',
#        'Farm', 'Fishing Spot', 'Seafood Restaurant', 'Athletics & Sports',
#        'Other Great Outdoors', 'Shanghai Restaurant',
#        'College Auditorium', 'Australian Restaurant', 'College Cafeteria',
#        'Dim Sum Restaurant', 'Food', 'Snack Place', 'Hobby Shop',
#        'Miscellaneous Shop', 'Bank', 'Modern European Restaurant',
#        'Pet Store', 'Dumpling Restaurant', 'Hakka Restaurant',
#        'Kids Store', 'Market', 'Metro Station', 'Chinese Breakfast Place',
#        'Gastropub', 'Hotel', 'Sporting Goods Shop', 'German Restaurant',
#        'Food Stand', 'Dance Studio', 'Spanish Restaurant',
#        'French Restaurant', 'Cocktail Bar', 'Club House', 'Buffet',
#        'Indonesian Restaurant', 'Scenic Lookout', 'Boutique',
#        'Chocolate Shop', 'Swiss Restaurant', 'Wine Bar', 'Whisky Bar',
#        'Museum', 'Arts & Crafts Store', 'Yoga Studio', 'Gift Shop',
#        'Soup Place', 'History Museum', 'Art Museum', 'Other Repair Shop',
#        'Art Gallery', 'Event Space', 'Plaza', 'Theater',
#        'General Entertainment', 'Concert Hall', 'Performing Arts Venue',
#        'Salad Place', 'Comfort Food Restaurant', 'Waterfront', 'Bridge',
#        'Vietnamese Restaurant', 'Outdoor Sculpture', 'Harbor / Marina',
#        'Brewery', 'Pub', 'Hotel Bar', 'Mexican Restaurant',
#        'Street Food Gathering', 'Church', 'Boat or Ferry', 'Cruise',
#        'Pier', 'High School', 'Water Park', 'Recreation Center',
#        'Skate Park', 'Kitchen Supply Store', 'South Indian Restaurant',
#        'Juice Bar', 'Flower Shop', 'Breakfast Spot',
#        'Thrift / Vintage Store', 'Burrito Place', 'Gas Station',
#        'Shabu-Shabu Restaurant', 'Climbing Gym', 'Boarding House',
#        'Food Truck', 'Hostel', 'Rock Club', 'Peruvian Restaurant',
#        'Hookah Bar', 'Sports Bar', 'Middle Eastern Restaurant',
#        'Mobile Phone Shop', 'Toy / Game Store', 'Salon / Barbershop',
#        'Bagel Shop', 'Kebab Restaurant', 'Tapas Restaurant',
#        'Deli / Bodega', 'Nail Salon', 'Buddhist Temple', 'Historic Site',
#        'Gay Bar', 'Cupcake Shop', 'Greek Restaurant', 'Motorcycle Shop',
#        'Canal', 'Gourmet Shop', 'Scandinavian Restaurant',
#        'Hot Dog Joint', 'Garden', 'Gym Pool', 'Liquor Store',
#        'Planetarium', 'Zoo Exhibit', 'Farmers Market', 'Wings Joint',
#        'Japanese Curry Restaurant', 'Warehouse Store',
#        'Distribution Center', 'Pool Hall', 'Nightclub', 'Arcade',
#        'Border Crossing', 'Cafeteria', 'Beach', 'Filipino Restaurant',
#        'Hardware Store', 'Coworking Space', 'Airport', 'Airport Lounge',
#        'Duty-free Shop', 'Public Art', 'Accessories Store', 'Candy Store',
#        'Smoke Shop', 'Martial Arts Dojo', 'River', 'Wine Shop',
#        'Massage Studio', 'Udon Restaurant', 'Neighborhood', 'Gaming Cafe',
#        'Dive Bar', 'Soccer Stadium', 'Soccer Field',
#        'Residential Building (Apartment / Condo)', 'Optical Shop',
#        'Bowling Green', 'Fish & Chips Shop', 'Betting Shop',
#        'Baseball Field', "Doctor's Office", 'Sculpture Garden',
#        'English Restaurant', 'Hotel Pool', 'Theme Park Ride / Attraction',
#        'Rock Climbing Spot', 'Fujian Restaurant',
#        'Chinese Aristocrat Restaurant', 'Szechuan Restaurant',
#        'Reservoir', 'Pie Shop', 'Non-Profit', 'Stables', 'Garden Center',
#        'Botanical Garden', 'Track Stadium', 'Beer Bar', 'TV Station',
#        'Medical Center', 'Island', 'Board Shop', 'Mountain', 'Resort',
#        'Roof Deck', 'Casino', 'Bay', 'Light Rail Station',
#        'Health Food Store', 'Nature Preserve', 'Beer Store',
#        'Churrascaria', 'Pet Service', 'General College & University',
#        'Mediterranean Restaurant', 'Sake Bar', 'Pedestrian Plaza',
#        'Laundromat', 'College Stadium', 'Housing Development'],
#       dtype=object)

# %%
# Here, we shall extract data of food establishments only
sg_food = sg_venues[sg_venues['Venue Category'].str.contains('Restaurant|Coffee|Food|Burger|Café|Hawker')]
sg_food.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1   Jurong East               1.333153              103.742287
# 5   Jurong East               1.333153              103.742287
# 8   Jurong East               1.333153              103.742287
# 10  Jurong East               1.333153              103.742287
# 12  Jurong East               1.333153              103.742287
#
#                                                 Venue  Venue Latitude  \
# 1   Tonkatsu by Ma Maison とんかつ マメゾン (Tonkatsu by M...        1.333668
# 5                                           Green Dot        1.333641
# 8                                    Dian Xiao Er 店小二        1.333447
# 10                              Paradise Dynasty 樂天皇朝        1.334364
# 12  Tsukada Nojo 塚田農場 Japanese "Bijin Nabe" Restau...        1.333718
#
#     Venue Longitude                 Venue Category
# 1        103.742818            Japanese Restaurant
# 5        103.742858  Vegetarian / Vegan Restaurant
# 8        103.743094             Chinese Restaurant
# 10       103.743612             Chinese Restaurant
# 12       103.742498            Japanese Restaurant

# %%
# one hot encoding
sg_onehot = pd.get_dummies(sg_food[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
sg_onehot['Neighborhood'] = sg_food['Neighborhood'] 


# move neighborhood column to the first column
fixed_columns = [sg_onehot.columns[list(sg_onehot.columns).index("Neighborhood")]] \
+ list(sg_onehot.columns[:list(sg_onehot.columns).index("Neighborhood")]) \
+list(sg_onehot.columns[list(sg_onehot.columns).index("Neighborhood")+1:])
sg_onehot = sg_onehot[fixed_columns]

sg_onehot.head()
# Out:
#    Neighborhood  American Restaurant  Asian Restaurant  Australian Restaurant  \
# 1   Jurong East                    0                 0                      0
# 5   Jurong East                    0                 0                      0
# 8   Jurong East                    0                 0                      0
# 10  Jurong East                    0                 0                      0
# 12  Jurong East                    0                 0                      0
#
#     Burger Joint  Café  Cantonese Restaurant  Chinese Aristocrat Restaurant  \
# 1              0     0                     0                              0
# 5              0     0                     0                              0
# 8              0     0                     0                              0
# 10             0     0                     0                              0
# 12             0     0                     0                              0
#
#     Chinese Restaurant  Coffee Shop  ...  Spanish Restaurant  \
# 1                    0            0  ...                   0
# 5                    0            0  ...                   0
# 8                    1            0  ...                   0
# 10                   1            0  ...                   0
# 12                   0            0  ...                   0
#
#     Street Food Gathering  Sushi Restaurant  Swiss Restaurant  \
# 1                       0                 0                 0
# 5                       0                 0                 0
# 8                       0                 0                 0
# 10                      0                 0                 0
# 12                      0                 0                 0
#
#     Szechuan Restaurant  Tapas Restaurant  Thai Restaurant  Udon Restaurant  \
# 1                     0                 0                0                0
# 5                     0                 0                0                0
# 8                     0                 0                0                0
# 10                    0                 0                0                0
# 12                    0                 0                0                0
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 1                               0                      0
# 5                               1                      0
# 8                               0                      0
# 10                              0                      0
# 12                              0                      0
#
# [5 rows x 62 columns]

# %%
# Check that we only have what we need
sg_onehot.columns
# Out:
# Index(['Neighborhood', 'American Restaurant', 'Asian Restaurant',
#        'Australian Restaurant', 'Burger Joint', 'Café', 'Cantonese Restaurant',
#        'Chinese Aristocrat Restaurant', 'Chinese Restaurant', 'Coffee Shop',
#        'Comfort Food Restaurant', 'Dim Sum Restaurant', 'Dumpling Restaurant',
#        'English Restaurant', 'Fast Food Restaurant', 'Filipino Restaurant',
#        'Food', 'Food & Drink Shop', 'Food Court', 'Food Stand', 'Food Truck',
#        'French Restaurant', 'Fujian Restaurant', 'German Restaurant',
#        'Greek Restaurant', 'Hainan Restaurant', 'Hakka Restaurant',
#        'Halal Restaurant', 'Health Food Store', 'Hong Kong Restaurant',
#        'Hotpot Restaurant', 'Indian Restaurant', 'Indonesian Restaurant',
#        'Italian Restaurant', 'Japanese Curry Restaurant',
#        'Japanese Restaurant', 'Kebab Restaurant', 'Korean Restaurant',
#        'Malay Restaurant', 'Mediterranean Restaurant', 'Mexican Restaurant',
#        'Middle Eastern Restaurant', 'Modern European Restaurant',
#        'Peruvian Restaurant', 'Portuguese Restaurant', 'Ramen Restaurant',
#        'Restaurant', 'Scandinavian Restaurant', 'Seafood Restaurant',
#        'Shabu-Shabu Restaurant', 'Shanghai Restaurant',
#        'South Indian Restaurant', 'Spanish Restaurant',
#        'Street Food Gathering', 'Sushi Restaurant', 'Swiss Restaurant',
#        'Szechuan Restaurant', 'Tapas Restaurant', 'Thai Restaurant',
#        'Udon Restaurant', 'Vegetarian / Vegan Restaurant',
#        'Vietnamese Restaurant'],
#       dtype='object')

# %%
# From above, we find that there is one venue category that does not fit well with our story
# Health Food Store seems more like a health supplement store than a food establishment
# So we shall remove this from our analysis
sg_grouped = sg_onehot.groupby('Neighborhood').mean().reset_index()
sg_grouped = sg_grouped.drop(['Health Food Store'], axis = 1)
sg_grouped.head()
# Out:
#   Neighborhood  American Restaurant  Asian Restaurant  Australian Restaurant  \
# 0    Admiralty                  0.0          0.000000                    0.0
# 1     Aljunied                  0.0          0.050000                    0.0
# 2   Ang Mo Kio                  0.0          0.090909                    0.0
# 3      Bartley                  0.0          0.062500                    0.0
# 4     Bayfront                  0.0          0.000000                    0.0
#
#    Burger Joint      Café  Cantonese Restaurant  \
# 0      0.000000  0.083333                  0.00
# 1      0.000000  0.100000                  0.05
# 2      0.090909  0.090909                  0.00
# 3      0.000000  0.125000                  0.00
# 4      0.000000  0.000000                  0.00
#
#    Chinese Aristocrat Restaurant  Chinese Restaurant  Coffee Shop  ...  \
# 0                         0.0000            0.000000     0.166667  ...
# 1                         0.0000            0.250000     0.000000  ...
# 2                         0.0000            0.090909     0.181818  ...
# 3                         0.0625            0.062500     0.062500  ...
# 4                         0.0000            0.000000     0.000000  ...
#
#    Spanish Restaurant  Street Food Gathering  Sushi Restaurant  \
# 0                 0.0                    0.0          0.000000
# 1                 0.0                    0.0          0.000000
# 2                 0.0                    0.0          0.090909
# 3                 0.0                    0.0          0.000000
# 4                 0.0                    0.0          0.000000
#
#    Swiss Restaurant  Szechuan Restaurant  Tapas Restaurant  Thai Restaurant  \
# 0               0.0               0.0000               0.0              0.0
# 1               0.0               0.0000               0.0              0.0
# 2               0.0               0.0000               0.0              0.0
# 3               0.0               0.0625               0.0              0.0
# 4               0.0               0.0000               0.0              0.0
#
#    Udon Restaurant  Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0              0.0                          0.000                    0.0
# 1              0.0                          0.150                    0.0
# 2              0.0                          0.000                    0.0
# 3              0.0                          0.125                    0.0
# 4              0.0                          0.000                    0.0
#
# [5 rows x 61 columns]

# %%
# Generate a brief report of the top 5 venues in each town and their respective frequencies (max = 1)
num_top_venues = 5

for hood in sg_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = sg_grouped[sg_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Admiralty----
#                   venue  freq
# 0            Food Court  0.33
# 1  Fast Food Restaurant  0.25
# 2           Coffee Shop  0.17
# 3                  Café  0.08
# 4     Food & Drink Shop  0.08
#
#
# ----Aljunied----
#                            venue  freq
# 0             Chinese Restaurant  0.25
# 1  Vegetarian / Vegan Restaurant  0.15
# 2             Dim Sum Restaurant  0.10
# 3                     Food Court  0.10
# 4                           Café  0.10
#
#
# ----Ang Mo Kio----
#                  venue  freq
# 0  Japanese Restaurant  0.18
# 1          Coffee Shop  0.18
# 2         Burger Joint  0.09
# 3                 Café  0.09
# 4     Asian Restaurant  0.09
#
#
# ----Bartley----
#                            venue  freq
# 0                     Food Court  0.31
# 1  Vegetarian / Vegan Restaurant  0.12
# 2                           Café  0.12
# 3              Korean Restaurant  0.06
# 4             Chinese Restaurant  0.06
#
#
# ----Bayfront----
#                  venue  freq
# 0  Japanese Restaurant  0.25
# 1   Italian Restaurant  0.25
# 2  Dumpling Restaurant  0.25
# 3   Dim Sum Restaurant  0.25
# 4  American Restaurant  0.00
#
#
# ----Beauty World----
#                 venue  freq
# 0   Korean Restaurant  0.19
# 1                Café  0.12
# 2  Chinese Restaurant  0.12
# 3     Thai Restaurant  0.12
# 4          Food Court  0.12
#
#
# ----Bedok----
#                 venue  freq
# 0         Coffee Shop  0.16
# 1  Chinese Restaurant  0.16
# 2          Food Court  0.11
# 3   Indian Restaurant  0.05
# 4    Asian Restaurant  0.05
#
#
# ----Bedok North----
#                   venue  freq
# 0            Food Court  0.20
# 1     Indian Restaurant  0.20
# 2           Coffee Shop  0.20
# 3  Fast Food Restaurant  0.15
# 4      Asian Restaurant  0.10
#
#
# ----Bedok Reservoir----
#                   venue  freq
# 0    Chinese Restaurant  0.21
# 1      Asian Restaurant  0.16
# 2            Food Court  0.11
# 3  Fast Food Restaurant  0.11
# 4                  Café  0.11
#
#
# ----Bencoolen----
#                            venue  freq
# 0                           Café  0.33
# 1                    Coffee Shop  0.17
# 2            Japanese Restaurant  0.08
# 3            Dumpling Restaurant  0.08
# 4  Vegetarian / Vegan Restaurant  0.08
#
#
# ----Bendemeer----
#                 venue  freq
# 0  Chinese Restaurant  0.42
# 1         Coffee Shop  0.17
# 2   Indian Restaurant  0.17
# 3          Restaurant  0.17
# 4  Dim Sum Restaurant  0.08
#
#
# ----Bishan----
#                  venue  freq
# 0  Japanese Restaurant  0.20
# 1          Coffee Shop  0.20
# 2      Thai Restaurant  0.13
# 3   Chinese Restaurant  0.13
# 4           Food Court  0.07
#
#
# ----Boon Keng----
#                 venue  freq
# 0  Chinese Restaurant  0.36
# 1          Food Court  0.18
# 2   Indian Restaurant  0.09
# 3                Food  0.09
# 4          Restaurant  0.09
#
#
# ----Boon Lay----
#                   venue  freq
# 0   Japanese Restaurant  0.22
# 1  Fast Food Restaurant  0.17
# 2    Chinese Restaurant  0.17
# 3      Asian Restaurant  0.09
# 4                  Café  0.09
#
#
# ----Botanic Gardens----
#                  venue  freq
# 0     Malay Restaurant  0.11
# 1   Spanish Restaurant  0.11
# 2  Japanese Restaurant  0.11
# 3                 Café  0.11
# 4   Chinese Restaurant  0.11
#
#
# ----Braddell----
#                 venue  freq
# 0  Chinese Restaurant  0.27
# 1    Asian Restaurant  0.18
# 2  Seafood Restaurant  0.09
# 3          Food Court  0.09
# 4                Café  0.09
#
#
# ----Bras Basah----
#                        venue  freq
# 0                       Café  0.23
# 1        Japanese Restaurant  0.15
# 2          French Restaurant  0.15
# 3                Coffee Shop  0.15
# 4  Middle Eastern Restaurant  0.08
#
#
# ----Buangkok----
#                    venue  freq
# 0             Food Court   0.4
# 1   Fast Food Restaurant   0.2
# 2  Indonesian Restaurant   0.1
# 3     Chinese Restaurant   0.1
# 4    Japanese Restaurant   0.1
#
#
# ----Bugis----
#                        venue  freq
# 0          Indian Restaurant  0.14
# 1        Japanese Restaurant  0.14
# 2  Middle Eastern Restaurant  0.14
# 3        Peruvian Restaurant  0.14
# 4           Ramen Restaurant  0.14
#
#
# ----Bukit Batok----
#                   venue  freq
# 0            Food Court  0.32
# 1           Coffee Shop  0.26
# 2      Malay Restaurant  0.11
# 3    Chinese Restaurant  0.11
# 4  Fast Food Restaurant  0.11
#
#
# ----Bukit Gombak----
#                            venue  freq
# 0                     Food Court  0.25
# 1                    Coffee Shop  0.19
# 2           Fast Food Restaurant  0.12
# 3             Chinese Restaurant  0.12
# 4  Vegetarian / Vegan Restaurant  0.06
#
#
# ----Bukit Panjang----
#                            venue  freq
# 0               Asian Restaurant  0.19
# 1                    Coffee Shop  0.19
# 2           Fast Food Restaurant  0.12
# 3            American Restaurant  0.06
# 4  Vegetarian / Vegan Restaurant  0.06
#
#
# ----Buona Vista----
#                  venue  freq
# 0   Chinese Restaurant  0.17
# 1  Japanese Restaurant  0.17
# 2    Indian Restaurant  0.17
# 3          Coffee Shop  0.17
# 4   Italian Restaurant  0.08
#
#
# ----Caldecott----
#                  venue  freq
# 0           Food Court   0.4
# 1                 Café   0.2
# 2     Hakka Restaurant   0.2
# 3    Hainan Restaurant   0.2
# 4  American Restaurant   0.0
#
#
# ----Cashew----
#                   venue  freq
# 0           Coffee Shop  0.23
# 1                  Café  0.15
# 2      Sushi Restaurant  0.15
# 3    Seafood Restaurant  0.08
# 4  Fast Food Restaurant  0.08
#
#
# ----Changi Airport----
#                    venue  freq
# 0     Chinese Restaurant  0.33
# 1    Japanese Restaurant  0.17
# 2   Cantonese Restaurant  0.17
# 3  Portuguese Restaurant  0.17
# 4            Coffee Shop  0.17
#
#
# ----Chinatown----
#                 venue  freq
# 0  Seafood Restaurant  0.17
# 1   Korean Restaurant  0.17
# 2                Café  0.17
# 3  Spanish Restaurant  0.17
# 4  Chinese Restaurant  0.08
#
#
# ----Chinese Garden----
#                 venue  freq
# 0          Food Court  0.16
# 1         Coffee Shop  0.16
# 2  Chinese Restaurant  0.16
# 3    Asian Restaurant  0.11
# 4   Indian Restaurant  0.11
#
#
# ----Choa Chu Kang----
#                   venue  freq
# 0  Fast Food Restaurant  0.27
# 1           Coffee Shop  0.27
# 2      Asian Restaurant  0.18
# 3            Food Court  0.09
# 4       Thai Restaurant  0.09
#
#
# ----City Hall----
#                  venue  freq
# 0    French Restaurant  0.22
# 1           Restaurant  0.11
# 2  Japanese Restaurant  0.11
# 3                 Café  0.11
# 4    Indian Restaurant  0.11
#
#
# ----Clarke Quay----
#                            venue  freq
# 0             Seafood Restaurant  0.15
# 1  Vegetarian / Vegan Restaurant  0.15
# 2             Spanish Restaurant  0.08
# 3               Asian Restaurant  0.08
# 4              Hotpot Restaurant  0.08
#
#
# ----Clementi----
#                 venue  freq
# 0          Food Court  0.21
# 1  Chinese Restaurant  0.21
# 2  Dim Sum Restaurant  0.07
# 3  Italian Restaurant  0.07
# 4    Asian Restaurant  0.07
#
#
# ----Commonwealth----
#                 venue  freq
# 0  Chinese Restaurant  0.26
# 1   Indian Restaurant  0.11
# 2                Café  0.11
# 3         Coffee Shop  0.11
# 4  Italian Restaurant  0.11
#
#
# ----Dakota----
#                    venue  freq
# 0     Chinese Restaurant  0.24
# 1     Seafood Restaurant  0.18
# 2                   Café  0.12
# 3  Vietnamese Restaurant  0.06
# 4     Dim Sum Restaurant  0.06
#
#
# ----Dhoby Ghaut----
#                         venue  freq
# 0                        Café  0.25
# 1       Indonesian Restaurant  0.12
# 2           Hotpot Restaurant  0.12
# 3           French Restaurant  0.12
# 4  Modern European Restaurant  0.12
#
#
# ----Dover----
#                   venue  freq
# 0           Coffee Shop  0.21
# 1     French Restaurant  0.14
# 2    Chinese Restaurant  0.07
# 3     Korean Restaurant  0.07
# 4  Fast Food Restaurant  0.07
#
#
# ----Downtown----
#                  venue  freq
# 0  Japanese Restaurant  0.15
# 1   Chinese Restaurant  0.15
# 2           Restaurant  0.08
# 3           Food Court  0.08
# 4   Spanish Restaurant  0.08
#
#
# ----Esplanade----
#                  venue  freq
# 0  Dumpling Restaurant  0.29
# 1  Japanese Restaurant  0.14
# 2     Ramen Restaurant  0.14
# 3    French Restaurant  0.14
# 4          Coffee Shop  0.14
#
#
# ----Eunos----
#                            venue  freq
# 0             Chinese Restaurant  0.21
# 1                     Food Court  0.16
# 2             Seafood Restaurant  0.11
# 3  Vegetarian / Vegan Restaurant  0.11
# 4               Asian Restaurant  0.11
#
#
# ----Expo----
#                  venue  freq
# 0          Coffee Shop  0.29
# 1           Food Court  0.14
# 2   Chinese Restaurant  0.14
# 3  Japanese Restaurant  0.14
# 4                 Café  0.07
#
#
# ----Farrer Park----
#                            venue  freq
# 0              Indian Restaurant  0.50
# 1             Chinese Restaurant  0.18
# 2  Vegetarian / Vegan Restaurant  0.09
# 3                           Café  0.09
# 4                     Food Court  0.05
#
#
# ----Farrer Road----
#                    venue  freq
# 0                   Café  0.26
# 1     Spanish Restaurant  0.11
# 2      French Restaurant  0.11
# 3     Chinese Restaurant  0.11
# 4  Indonesian Restaurant  0.05
#
#
# ----Fort Canning----
#                            venue  freq
# 0            Japanese Restaurant   0.4
# 1               Asian Restaurant   0.1
# 2  Vegetarian / Vegan Restaurant   0.1
# 3                Udon Restaurant   0.1
# 4              Hotpot Restaurant   0.1
#
#
# ----Geylang Bahru----
#                 venue  freq
# 0          Food Court  0.35
# 1  Chinese Restaurant  0.20
# 2    Asian Restaurant  0.10
# 3                Café  0.10
# 4   Indian Restaurant  0.05
#
#
# ----Gul Circle----
#               venue  freq
# 0       Coffee Shop  0.38
# 1        Food Court  0.25
# 2  Asian Restaurant  0.12
# 3              Food  0.12
# 4        Restaurant  0.12
#
#
# ----HarbourFront----
#                 venue  freq
# 0  Chinese Restaurant   0.2
# 1         Coffee Shop   0.2
# 2    Swiss Restaurant   0.1
# 3   German Restaurant   0.1
# 4    Sushi Restaurant   0.1
#
#
# ----Haw Par Villa----
#                    venue  freq
# 0       Asian Restaurant  0.23
# 1             Food Court  0.15
# 2            Coffee Shop  0.15
# 3  Vietnamese Restaurant  0.08
# 4     Chinese Restaurant  0.08
#
#
# ----Hillview----
#                  venue  freq
# 0   Italian Restaurant  0.18
# 1                 Café  0.18
# 2    Indian Restaurant  0.12
# 3          Coffee Shop  0.12
# 4  American Restaurant  0.06
#
#
# ----Holland Village----
#                  venue  freq
# 0   Chinese Restaurant  0.23
# 1   Italian Restaurant  0.15
# 2           Food Court  0.08
# 3  Japanese Restaurant  0.08
# 4   Dim Sum Restaurant  0.08
#
#
# ----Hougang----
#                            venue  freq
# 0                    Coffee Shop  0.17
# 1                     Food Court  0.17
# 2  Vegetarian / Vegan Restaurant  0.11
# 3               Asian Restaurant  0.11
# 4             Chinese Restaurant  0.11
#
#
# ----Jalan Besar----
#                            venue  freq
# 0              Indian Restaurant  0.39
# 1  Vegetarian / Vegan Restaurant  0.17
# 2             Chinese Restaurant  0.11
# 3               Ramen Restaurant  0.06
# 4             Italian Restaurant  0.06
#
#
# ----Joo Koon----
#                         venue  freq
# 0        Fast Food Restaurant  0.62
# 1                 Coffee Shop  0.12
# 2          Chinese Restaurant  0.12
# 3          Seafood Restaurant  0.12
# 4  Modern European Restaurant  0.00
#
#
# ----Jurong East----
#                            venue  freq
# 0             Chinese Restaurant  0.27
# 1            Japanese Restaurant  0.20
# 2  Vegetarian / Vegan Restaurant  0.07
# 3                   Burger Joint  0.07
# 4             Italian Restaurant  0.07
#
#
# ----Kaki Bukit----
#                 venue  freq
# 0          Food Court  0.29
# 1         Coffee Shop  0.21
# 2   Indian Restaurant  0.17
# 3    Asian Restaurant  0.08
# 4  Chinese Restaurant  0.08
#
#
# ----Kallang----
#                 venue  freq
# 0  Dim Sum Restaurant  0.25
# 1          Restaurant  0.25
# 2  Chinese Restaurant  0.25
# 3  Seafood Restaurant  0.12
# 4          Food Court  0.12
#
#
# ----Kembangan----
#                 venue  freq
# 0   Indian Restaurant  0.25
# 1  Chinese Restaurant  0.19
# 2          Food Court  0.12
# 3         Coffee Shop  0.12
# 4    Malay Restaurant  0.06
#
#
# ----Kent Ridge----
#                venue  freq
# 0        Coffee Shop  0.44
# 1  Indian Restaurant  0.11
# 2  Korean Restaurant  0.06
# 3         Food Court  0.06
# 4   Asian Restaurant  0.06
#
#
# ----Khatib----
#                   venue  freq
# 0           Coffee Shop  0.38
# 1            Food Court  0.15
# 2   American Restaurant  0.08
# 3    Chinese Restaurant  0.08
# 4  Fast Food Restaurant  0.08
#
#
# ----King Albert Park----
#                        venue  freq
# 0         Chinese Restaurant  0.24
# 1                 Food Court  0.18
# 2           Asian Restaurant  0.18
# 3          Indian Restaurant  0.12
# 4  Middle Eastern Restaurant  0.06
#
#
# ----Kovan----
#                            venue  freq
# 0             Chinese Restaurant  0.24
# 1                           Café  0.18
# 2               Asian Restaurant  0.18
# 3                    Coffee Shop  0.12
# 4  Vegetarian / Vegan Restaurant  0.06
#
#
# ----Kranji----
#                        venue  freq
# 0           Asian Restaurant   0.5
# 1                       Café   0.5
# 2    Scandinavian Restaurant   0.0
# 3  Japanese Curry Restaurant   0.0
# 4        Japanese Restaurant   0.0
#
#
# ----Labrador Park----
#                    venue  freq
# 0     Chinese Restaurant  0.29
# 1        Thai Restaurant  0.14
# 2            Coffee Shop  0.14
# 3  Vietnamese Restaurant  0.07
# 4     Mexican Restaurant  0.07
#
#
# ----Lakeside----
#                            venue  freq
# 0                    Coffee Shop  0.19
# 1                     Food Court  0.19
# 2               Asian Restaurant  0.12
# 3           Fast Food Restaurant  0.12
# 4  Vegetarian / Vegan Restaurant  0.06
#
#
# ----Lavender----
#                    venue  freq
# 0        Thai Restaurant  0.24
# 1             Restaurant  0.18
# 2  Indonesian Restaurant  0.06
# 3            Coffee Shop  0.06
# 4     Italian Restaurant  0.06
#
#
# ----Little India----
#                            venue  freq
# 0              Indian Restaurant  0.64
# 1  Vegetarian / Vegan Restaurant  0.18
# 2      Middle Eastern Restaurant  0.05
# 3                           Café  0.05
# 4           Cantonese Restaurant  0.05
#
#
# ----Lorong Chuan----
#                   venue  freq
# 0                  Café  0.22
# 1    Chinese Restaurant  0.22
# 2      Asian Restaurant  0.11
# 3   Japanese Restaurant  0.11
# 4  Fast Food Restaurant  0.11
#
#
# ----MacPherson----
#                 venue  freq
# 0    Asian Restaurant  0.25
# 1          Food Court  0.19
# 2  Seafood Restaurant  0.12
# 3         Coffee Shop  0.06
# 4    Ramen Restaurant  0.06
#
#
# ----Marina Bay----
#                  venue  freq
# 0   Mexican Restaurant  0.17
# 1           Restaurant  0.17
# 2  Japanese Restaurant  0.08
# 3          Coffee Shop  0.08
# 4           Food Court  0.08
#
#
# ----Marina South Pier----
#                        venue  freq
# 0         Mexican Restaurant   1.0
# 1        American Restaurant   0.0
# 2           Asian Restaurant   0.0
# 3  Japanese Curry Restaurant   0.0
# 4        Japanese Restaurant   0.0
#
#
# ----Marsiling----
#                   venue  freq
# 0            Food Court  0.23
# 1           Coffee Shop  0.23
# 2                  Café  0.15
# 3  Fast Food Restaurant  0.15
# 4          Burger Joint  0.08
#
#
# ----Marymount----
#                 venue  freq
# 0                Café  0.19
# 1     Thai Restaurant  0.19
# 2  Chinese Restaurant  0.12
# 3          Food Court  0.12
# 4   Korean Restaurant  0.06
#
#
# ----Mattar----
#                 venue  freq
# 0          Food Court  0.24
# 1    Asian Restaurant  0.14
# 2  Seafood Restaurant  0.14
# 3  Chinese Restaurant  0.14
# 4   Indian Restaurant  0.10
#
#
# ----Mountbatten----
#                   venue  freq
# 0    Chinese Restaurant  0.33
# 1    Seafood Restaurant  0.13
# 2      Malay Restaurant  0.07
# 3            Food Court  0.07
# 4  Fast Food Restaurant  0.07
#
#
# ----Newton----
#                    venue  freq
# 0    Japanese Restaurant  0.29
# 1     Chinese Restaurant  0.14
# 2  Indonesian Restaurant  0.07
# 3     Spanish Restaurant  0.07
# 4      French Restaurant  0.07
#
#
# ----Nicoll Highway----
#                    venue  freq
# 0        Thai Restaurant  0.33
# 1  Vietnamese Restaurant  0.11
# 2             Restaurant  0.11
# 3     Italian Restaurant  0.11
# 4            Coffee Shop  0.06
#
#
# ----Novena----
#                            venue  freq
# 0                    Coffee Shop   0.2
# 1  Vegetarian / Vegan Restaurant   0.1
# 2                           Café   0.1
# 3             Italian Restaurant   0.1
# 4             Chinese Restaurant   0.1
#
#
# ----Orchard----
#                    venue  freq
# 0       Sushi Restaurant  0.25
# 1  Indonesian Restaurant  0.12
# 2     Chinese Restaurant  0.12
# 3    Japanese Restaurant  0.12
# 4             Restaurant  0.12
#
#
# ----Outram Park----
#                    venue  freq
# 0    Japanese Restaurant  0.11
# 1  Australian Restaurant  0.11
# 2                   Café  0.11
# 3     Chinese Restaurant  0.11
# 4            Coffee Shop  0.11
#
#
# ----Pasir Panjang----
#                 venue  freq
# 0  Chinese Restaurant  0.22
# 1         Coffee Shop  0.11
# 2          Food Court  0.11
# 3                Café  0.11
# 4     Thai Restaurant  0.11
#
#
# ----Pasir Ris----
#                   venue  freq
# 0            Food Court  0.12
# 1                  Café  0.12
# 2  Fast Food Restaurant  0.12
# 3           Coffee Shop  0.12
# 4      Sushi Restaurant  0.06
#
#
# ----Paya Lebar----
#                            venue  freq
# 0             Chinese Restaurant  0.20
# 1               Asian Restaurant  0.15
# 2          Vietnamese Restaurant  0.10
# 3  Vegetarian / Vegan Restaurant  0.10
# 4                     Food Court  0.10
#
#
# ----Pioneer----
#                   venue  freq
# 0           Coffee Shop  0.22
# 1  Fast Food Restaurant  0.17
# 2   Japanese Restaurant  0.11
# 3    Chinese Restaurant  0.11
# 4      Sushi Restaurant  0.06
#
#
# ----Potong Pasir----
#                   venue  freq
# 0    Chinese Restaurant  0.28
# 1            Food Court  0.17
# 2  Fast Food Restaurant  0.17
# 3      Asian Restaurant  0.11
# 4            Restaurant  0.06
#
#
# ----Promenade----
#                  venue  freq
# 0  Japanese Restaurant  0.50
# 1                 Café  0.17
# 2    German Restaurant  0.17
# 3           Restaurant  0.17
# 4  American Restaurant  0.00
#
#
# ----Punggol----
#                   venue  freq
# 0  Fast Food Restaurant  0.19
# 1            Food Court  0.12
# 2    Chinese Restaurant  0.12
# 3           Coffee Shop  0.06
# 4      Asian Restaurant  0.06
#
#
# ----Queenstown----
#                 venue  freq
# 0          Food Court  0.18
# 1                Café  0.12
# 2    Malay Restaurant  0.12
# 3  Chinese Restaurant  0.12
# 4         Coffee Shop  0.12
#
#
# ----Raffles Place----
#                  venue  freq
# 0  Japanese Restaurant  0.14
# 1          Coffee Shop  0.14
# 2   Italian Restaurant  0.07
# 3     Asian Restaurant  0.07
# 4    Hotpot Restaurant  0.07
#
#
# ----Redhill----
#                 venue  freq
# 0  Chinese Restaurant  0.32
# 1         Coffee Shop  0.21
# 2                Café  0.21
# 3          Food Court  0.11
# 4    Malay Restaurant  0.05
#
#
# ----Rochor----
#                            venue  freq
# 0              Indian Restaurant  0.33
# 1  Vegetarian / Vegan Restaurant  0.17
# 2                           Café  0.11
# 3             Chinese Restaurant  0.11
# 4                     Food Court  0.06
#
#
# ----Sembawang----
#                   venue  freq
# 0           Coffee Shop  0.21
# 1    Chinese Restaurant  0.21
# 2      Asian Restaurant  0.08
# 3                  Café  0.08
# 4  Fast Food Restaurant  0.08
#
#
# ----Sengkang----
#                   venue  freq
# 0  Fast Food Restaurant  0.24
# 1                  Café  0.12
# 2            Food Court  0.12
# 3    Chinese Restaurant  0.12
# 4      Sushi Restaurant  0.12
#
#
# ----Serangoon----
#                            venue  freq
# 0             Chinese Restaurant  0.25
# 1                    Coffee Shop  0.17
# 2  Vegetarian / Vegan Restaurant  0.08
# 3               Asian Restaurant  0.08
# 4                           Café  0.08
#
#
# ----Simei----
#                      venue  freq
# 0              Coffee Shop  0.25
# 1     Fast Food Restaurant  0.15
# 2       Seafood Restaurant  0.10
# 3       Chinese Restaurant  0.10
# 4  South Indian Restaurant  0.05
#
#
# ----Sixth Avenue----
#                  venue  freq
# 0  Japanese Restaurant  0.25
# 
# 1              Food  0.25
# 2  Asian Restaurant  0.25
# 3   Udon Restaurant  0.00
# 4   Thai Restaurant  0.00
#
#
# ----Tuas Link----
#                      venue  freq
# 0       Chinese Restaurant   1.0
# 1      American Restaurant   0.0
# 2  Scandinavian Restaurant   0.0
# 3      Japanese Restaurant   0.0
# 4         Kebab Restaurant   0.0
#
#
# ----Tuas West Road----
#                      venue  freq
# 0              Coffee Shop   0.5
# 1               Food Court   0.5
# 2      American Restaurant   0.0
# 3  Scandinavian Restaurant   0.0
# 4      Japanese Restaurant   0.0
#
#
# ----Ubi----
#                  venue  freq
# 0           Food Court  0.27
# 1          Coffee Shop  0.27
# 2     Asian Restaurant  0.14
# 3   Chinese Restaurant  0.14
# 4  Japanese Restaurant  0.09
#
#
# ----Upper Changi----
#                  venue  freq
# 0          Coffee Shop  0.25
# 1  Japanese Restaurant  0.19
# 2   Chinese Restaurant  0.12
# 3           Food Court  0.12
# 4                 Café  0.06
#
#
# ----Woodlands----
#                   venue  freq
# 0                  Café  0.25
# 1            Food Court  0.19
# 2    Chinese Restaurant  0.12
# 3   Japanese Restaurant  0.12
# 4  Fast Food Restaurant  0.06
#
#
# ----Woodleigh----
#                   venue  freq
# 0      Asian Restaurant   0.2
# 1           Coffee Shop   0.2
# 2  Fast Food Restaurant   0.2
# 3            Food Court   0.1
# 4     Indian Restaurant   0.1
#
#
# ----Yew Tee----
#                   venue  freq
# 0  Fast Food Restaurant   0.3
# 1            Food Court   0.2
# 2      Asian Restaurant   0.1
# 3   Japanese Restaurant   0.1
# 4                  Café   0.1
#
#
# ----Yio Chu Kang----
#                    venue  freq
# 0             Food Court  0.28
# 1     Chinese Restaurant  0.17
# 2            Coffee Shop  0.11
# 3                   Food  0.06
# 4  Australian Restaurant  0.06
#
#
# ----Yishun----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1   Indian Restaurant  0.12
# 2     Thai Restaurant  0.12
# 3  Chinese Restaurant  0.12
# 4          Food Court  0.06
#
#
# ----one-north----
#                  venue  freq
# 0          Coffee Shop  0.21
# 1  Japanese Restaurant  0.14
# 2                 Café  0.14
# 3   Italian Restaurant  0.07
# 4     Malay Restaurant  0.07

# %%
# Create function to return most common venue for each town, based on a defined number num_top_venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = sg_grouped['Neighborhood']

for ind in np.arange(sg_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sg_grouped.iloc[ind, :], num_top_venues)

# A deeper look into the top 10 venues in each town
neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue          2nd Most Common Venue  \
# 0    Admiralty            Food Court           Fast Food Restaurant
# 1     Aljunied    Chinese Restaurant  Vegetarian / Vegan Restaurant
# 2   Ang Mo Kio   Japanese Restaurant                    Coffee Shop
# 3      Bartley            Food Court  Vegetarian / Vegan Restaurant
# 4     Bayfront    Italian Restaurant            Japanese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue       5th Most Common Venue  \
# 0           Coffee Shop     Food & Drink Shop                        Café
# 1                  Café            Food Court          Seafood Restaurant
# 2      Halal Restaurant      Sushi Restaurant  Modern European Restaurant
# 3                  Café     Korean Restaurant                 Coffee Shop
# 4    Dim Sum Restaurant   Dumpling Restaurant       Vietnamese Restaurant
#
#            6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 0               Malay Restaurant  Vietnamese Restaurant      Halal Restaurant
# 1             Dim Sum Restaurant      Korean Restaurant      Asian Restaurant
# 2             Chinese Restaurant                   Café          Burger Joint
# 3  Chinese Aristocrat Restaurant     Chinese Restaurant   Szechuan Restaurant
# 4              Food & Drink Shop       Halal Restaurant      Hakka Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Hakka Restaurant      Hainan Restaurant
# 1            Food Truck   Cantonese Restaurant
# 2      Asian Restaurant      Hainan Restaurant
# 3      Halal Restaurant       Asian Restaurant
# 4     Hainan Restaurant       Greek Restaurant

# %% [markdown]
# # 4. Create Clusters based on Food Establishment
# Now that we have identified the top 10 venues of each town, we can cluster the towns based on how similar they are in terms of their food establishment. By doing so, it may give us some insights to how similar each town is.

# %%
# set number of clusters = 3

kclusters = 3

sg_grouped_clustering = sg_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sg_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 1, 0, 1, 2, 2, 0, 2, 1])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

sg_merged = sg_df

# merge neighborhoods_venues_sorted with sg_df to add latitude/longitude for each neighborhood
sg_merged = sg_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='STATION NAME')

sg_merged.head() # check the last columns!
# Out:
#     STATION NAME STATION  POSTAL   LONGITUDE  LATITUDE  Cluster Labels  \
# 0    Jurong East     NS1  609690  103.742287  1.333153               2
# 1    Bukit Batok     NS2  659958  103.749567  1.349034               0
# 2   Bukit Gombak     NS3  659083  103.751791  1.358612               0
# 3  Choa Chu Kang     NS4  689810  103.744371  1.385363               0
# 4        Yew Tee     NS5  689715  103.747405  1.397535               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0    Chinese Restaurant   Japanese Restaurant    Italian Restaurant
# 1            Food Court           Coffee Shop    Chinese Restaurant
# 2            Food Court           Coffee Shop    Chinese Restaurant
# 3  Fast Food Restaurant           Coffee Shop      Asian Restaurant
# 4  Fast Food Restaurant            Food Court                  Café
#
#   4th Most Common Venue 5th Most Common Venue  6th Most Common Venue  \
# 0      Halal Restaurant     Korean Restaurant       Sushi Restaurant
# 1      Malay Restaurant  Fast Food Restaurant     Italian Restaurant
# 2  Fast Food Restaurant     Indian Restaurant     Italian Restaurant
# 3       Thai Restaurant            Food Court  Portuguese Restaurant
# 4   Japanese Restaurant            Restaurant       Asian Restaurant
#
#   7th Most Common Venue          8th Most Common Venue  \
# 0     Indian Restaurant                   Burger Joint
# 1                  Café                     Food Truck
# 2      Malay Restaurant  Vegetarian / Vegan Restaurant
# 3     Food & Drink Shop                     Food Stand
# 4    Chinese Restaurant               Hakka Restaurant
#
#            9th Most Common Venue         10th Most Common Venue
# 0  Vegetarian / Vegan Restaurant              Hotpot Restaurant
# 1              French Restaurant              Fujian Restaurant
# 2               Asian Restaurant  Chinese Aristocrat Restaurant
# 3                     Food Truck              French Restaurant
# 4              Hainan Restaurant               Halal Restaurant

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sg_merged['LATITUDE'], sg_merged['LONGITUDE'], sg_merged['STATION NAME'], sg_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looking at the map, we can see a clear distinction between the East, West, North and Central Singapore.<br><br>
#
# East Singapore is heavily occupied by cluster 2 whereas West Singapore is predominantly cluster 0. Central and Downtown (Southern) Singapore is mainly made up of cluster 1. Northern Singapore is much more similar to West Singapore where mainly cluster 1 resides. <br><br>
#
# Let's have a deeper look into the clusters to see what's the difference.

# %% [markdown]
# ### Cluster 0

# %%
# 134                    Coffee Shop                     Food Court
# 136              Indian Restaurant           Fast Food Restaurant
# 138           Fast Food Restaurant                     Food Court
# 139            Japanese Restaurant                     Food Court
#
#        4th Most Common Venue  5th Most Common Venue
# 1           Malay Restaurant   Fast Food Restaurant
# 2       Fast Food Restaurant      Indian Restaurant
# 3            Thai Restaurant             Food Court
# 4        Japanese Restaurant             Restaurant
# 6       Fast Food Restaurant       Asian Restaurant
# 8          Food & Drink Shop                   Café
# 11        Seafood Restaurant    American Restaurant
# 12                      Food   Fast Food Restaurant
# 26                      Café    American Restaurant
# 28        Seafood Restaurant    Japanese Restaurant
# 47                Food Court      Korean Restaurant
# 50         Indian Restaurant       Asian Restaurant
# 51          Asian Restaurant       Halal Restaurant
# 53        Chinese Restaurant                   Café
# 54        Seafood Restaurant                   Food
# 55          Asian Restaurant                   Food
# 56     Vietnamese Restaurant   Hong Kong Restaurant
# 57                      Food   Hong Kong Restaurant
# 59                Food Court      Indian Restaurant
# 70         Indian Restaurant             Food Court
# 73        Chinese Restaurant   Fast Food Restaurant
# 74       Japanese Restaurant     Chinese Restaurant
# 75          Sushi Restaurant             Food Court
# 76     Vietnamese Restaurant     Seafood Restaurant
# 86               Coffee Shop   Fast Food Restaurant
# 88         Korean Restaurant            Coffee Shop
# 93         Hainan Restaurant  Vietnamese Restaurant
# 99          Kebab Restaurant      Korean Restaurant
# 100    Vietnamese Restaurant      Korean Restaurant
# 107      American Restaurant        Thai Restaurant
# 132         Asian Restaurant    Japanese Restaurant
# 133       Chinese Restaurant       Asian Restaurant
# 134     Fast Food Restaurant       Asian Restaurant
# 136         Halal Restaurant     Seafood Restaurant
# 138  South Indian Restaurant     Seafood Restaurant
# 139       Chinese Restaurant      Hotpot Restaurant

# %% [markdown]
# From above, we see that in cluster 0, the towns have more coffee shops, food courts and fast food restaurants than cuisine-specific restaurants.<br>
#
# Background: Coffee shops and Food Courts (sometimes known as <a href = https://en.wikipedia.org/wiki/Hawker_centre>Hawker centres</a>) are centralized food establishments. One can find many kinds of food in food courts, such as Chinese, Malay, Indian, Western and Local Delights. While the food sold in food courts is relatively inexpensive, the food tastes delicious. Due to its affordability, most Singaporeans patron food courts for a hearty meal!

# %% [markdown]
# ### Cluster 1

# %%
sg_merged.loc[sg_merged['Cluster Labels'] == 1, sg_merged.columns[[0] + list(range(5, 11))]]
# Out:
#           STATION NAME  Cluster Labels          1st Most Common Venue  \
# 5               Kranji               1               Asian Restaurant
# 7            Woodlands               1                           Café
# 13          Ang Mo Kio               1            Japanese Restaurant
# 14              Bishan               1            Japanese Restaurant
# 17              Novena               1                    Coffee Shop
# 18              Newton               1            Japanese Restaurant
# 19             Orchard               1               Sushi Restaurant
# 20            Somerset               1            Japanese Restaurant
# 21         Dhoby Ghaut               1                           Café
# 22           City Hall               1              French Restaurant
# 23       Raffles Place               1                    Coffee Shop
# 24          Marina Bay               1             Mexican Restaurant
# 25   Marina South Pier               1             Mexican Restaurant
# 113                           Café            Malay Restaurant
# 115                           Café           Indian Restaurant
# 122            Japanese Restaurant          Spanish Restaurant
# 123             Italian Restaurant                        Café
# 125              Hotpot Restaurant          Seafood Restaurant
# 126                    Coffee Shop  Modern European Restaurant
#
#              4th Most Common Venue          5th Most Common Venue
# 5                             Food           Hong Kong Restaurant
# 7              Japanese Restaurant              Indian Restaurant
# 13                Sushi Restaurant     Modern European Restaurant
# 14                 Thai Restaurant                     Food Court
# 17                            Café             Chinese Restaurant
# 18              Seafood Restaurant                Thai Restaurant
# 19           Indonesian Restaurant                     Restaurant
# 20               Korean Restaurant            Dumpling Restaurant
# 21      Modern European Restaurant          Indonesian Restaurant
# 22             Japanese Restaurant            Dumpling Restaurant
# 23              Italian Restaurant                     Food Court
# 24                      Food Court             Seafood Restaurant
# 25                Halal Restaurant               Hakka Restaurant
# 27              Chinese Restaurant            Japanese Restaurant
# 36                    Burger Joint                           Café
# 37             Japanese Restaurant                     Food Court
# 40                Tapas Restaurant               Ramen Restaurant
# 41             Japanese Restaurant                           Café
# 42                      Food Court              Hainan Restaurant
# 44                            Café             Chinese Restaurant
# 46                     Coffee Shop             Italian Restaurant
# 52                            Café               Asian Restaurant
# 63               Korean Restaurant             Chinese Restaurant
# 64             Japanese Restaurant             Italian Restaurant
# 78                     Coffee Shop     Modern European Restaurant
# 79               French Restaurant                    Coffee Shop
# 80               German Restaurant            Filipino Restaurant
# 81              Italian Restaurant               Asian Restaurant
# 82                 Thai Restaurant             Mexican Restaurant
# 90             Japanese Restaurant               Sushi Restaurant
# 94                Malay Restaurant            Japanese Restaurant
# 95               French Restaurant               Asian Restaurant
# 98              Chinese Restaurant      Middle Eastern Restaurant
# 105            Dumpling Restaurant          Vietnamese Restaurant
# 108           Fast Food Restaurant           Cantonese Restaurant
# 109                    Coffee Shop             Seafood Restaurant
# 112                     Restaurant             Seafood Restaurant
# 113             Chinese Restaurant            Japanese Restaurant
# 115             Chinese Restaurant            Japanese Restaurant
# 122             Mexican Restaurant                     Restaurant
# 123                     Food Court     Modern European Restaurant
# 125  Vegetarian / Vegan Restaurant               Ramen Restaurant
# 126              French Restaurant  Vegetarian / Vegan Restaurant

# %% [markdown]
# Cluster 1 towns have restaurants that are generally more exotic, such as Japanese, European, Korean and even Cafés. Looking at the type of food establishments, the food sold in towns are likely to be more expensive. <br><br>
# Except for Kranji, the towns marked as cluster 1 are relative central. Tampines and Woodlands are exceptions also, but they are commercial hubs where many office buildings are located. <br><br>
# Most cluster 1 towns are in the downtown, where the Central Business District and the Tourist Hotspots are. Hence it is expected that food variety is greater and costs more expensive in these areas.

# %% [markdown]
# ### Cluster 2

# %%
sg_merged.loc[sg_merged['Cluster Labels'] == 2, sg_merged.columns[[0] + list(range(5, 11))]]
# Out:
#          STATION NAME  Cluster Labels 1st Most Common Venue  \
# 0         Jurong East               2    Chinese Restaurant
# 9           Sembawang               2    Chinese Restaurant
# 10             Yishun               2     Indian Restaurant
